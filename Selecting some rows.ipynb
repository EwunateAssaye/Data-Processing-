# %%
import pandas as pd
data = pd.read_csv('C:/Users/Ewunetie/OneDrive - University of Gondar,/2022-2023 files/Courses/ML Project/Data/Preprocessed/final_mergid.csv')  
data
# Out:
#               0         1         2         3         4         5         6  \
# 0      0.091106  0.518698  0.454739  0.443264  0.477215  0.404772  0.353674
# 1     -0.034439 -0.171477 -0.206294 -0.210841 -0.194814 -0.149334 -0.112995
# 2      0.020083  0.003027  0.005759  0.013765  0.020983  0.017463  0.020858
# 3     -0.014241  0.042690  0.374975  0.767974  0.972632  0.764714  0.106351
# 4     -0.001045 -0.197443  0.061207  0.247844  0.273315  0.269234  0.250208
# ...         ...       ...       ...       ...       ...       ...       ...
# 18845  0.015151  0.065536  0.057721  0.048234  0.047437  0.047215  0.031900
# 18846  0.246921  0.230755  0.198170  0.181397  0.155857  0.167862  0.326844
# 18847 -0.003068  0.013295  0.019870  0.005859  0.010370  0.003374 -0.012807
# 18848 -0.028033 -0.054476 -0.044379 -0.037059 -0.023464 -0.028196 -0.027126
# 18849  0.005965 -0.025268 -0.027361  0.001706  0.062255  0.092350  0.018881
#
# ...

# %%
some_rows = data.iloc[0:10000]
some_rows
# titanic.iloc[9:25, 2:5] # I’m interested in rows 10 till 25 and columns 3 to 5
# Out:
#              0         1         2         3         4         5         6  \
# 0     0.091106  0.518698  0.454739  0.443264  0.477215  0.404772  0.353674
# 1    -0.034439 -0.171477 -0.206294 -0.210841 -0.194814 -0.149334 -0.112995
# 2     0.020083  0.003027  0.005759  0.013765  0.020983  0.017463  0.020858
# 3    -0.014241  0.042690  0.374975  0.767974  0.972632  0.764714  0.106351
# 4    -0.001045 -0.197443  0.061207  0.247844  0.273315  0.269234  0.250208
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995 -0.036068 -0.028318  0.008204 -0.021498 -0.106087 -0.077251 -0.029170
# 9996 -0.027039 -0.005891 -0.028906 -0.047815 -0.099150 -0.171669 -0.186860
# 9997  0.003288  0.009163  0.003048  0.001964  0.000666 -0.006761 -0.005566
# 9998 -0.025432 -0.135261 -0.258576 -0.345533 -0.238348 -0.038057  0.039122
# 9999 -0.026845  0.030045  0.075842  0.081961  0.075814  0.081931  0.083096
#
# ...

# %%
import os
path = 'C:/Users/Ewunetie/OneDrive - University of Gondar,/2022-2023 files/Courses/ML Project/Data/Preprocessed'
files = os.listdir(path)
output_file_path = os.path.join(path,"10000_data.csv")
some_rows.to_csv(output_file_path, index=False)

# %%
some_rows
# Out:
#              0         1         2         3         4         5         6  \
# 0     0.091106  0.518698  0.454739  0.443264  0.477215  0.404772  0.353674
# 1    -0.034439 -0.171477 -0.206294 -0.210841 -0.194814 -0.149334 -0.112995
# 2     0.020083  0.003027  0.005759  0.013765  0.020983  0.017463  0.020858
# 3    -0.014241  0.042690  0.374975  0.767974  0.972632  0.764714  0.106351
# 4    -0.001045 -0.197443  0.061207  0.247844  0.273315  0.269234  0.250208
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995 -0.036068 -0.028318  0.008204 -0.021498 -0.106087 -0.077251 -0.029170
# 9996 -0.027039 -0.005891 -0.028906 -0.047815 -0.099150 -0.171669 -0.186860
# 9997  0.003288  0.009163  0.003048  0.001964  0.000666 -0.006761 -0.005566
# 9998 -0.025432 -0.135261 -0.258576 -0.345533 -0.238348 -0.038057  0.039122
# 9999 -0.026845  0.030045  0.075842  0.081961  0.075814  0.081931  0.083096
#
# ...
