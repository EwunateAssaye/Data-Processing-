# %%
from scipy.signal import find_peaks, butter, filtfilt
import biosppy.signals.ecg as ecg
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os

path1='C:/Users/Ewunetie/OneDrive - University of Gondar,/2022-2023 files/Courses/ML Project/Data/Aug_44000.csv'
df = pd.read_csv(path1)
df
# Out:
#        1250         0         1         2         3         4         5  \
# 0        90  0.203872  0.164818  0.130023  0.094775  0.046829 -0.003756
# 1        90  0.942383  0.811564  0.220400 -0.277604 -0.347948 -0.173419
# 2        90 -0.084261 -0.078485 -0.069727 -0.067950 -0.074010 -0.076896
# 3        90 -0.065942 -0.071938 -0.070998 -0.049678 -0.017488  0.008951
# 4        90 -0.116445 -0.111806 -0.092861 -0.068614 -0.056336 -0.052929
# ...     ...       ...       ...       ...       ...       ...       ...
# 43898    54 -0.097649 -0.058406 -0.050236  0.011217  0.025881  0.092275
# 43899    54 -0.058426 -0.093546 -0.046176 -0.051968 -0.093528 -0.090619
# 43900    54  0.094591  0.089926  0.116001  0.153270  0.329059  0.507430
# 43901    54 -0.219910 -0.162454 -0.126446 -0.065053 -0.034982  0.054157
# 43902    54  0.184890  0.195797  0.144801  0.201914  0.190099  0.304728
#
#               6         7         8  ...      1240      1241      1242  \
# ...

# %%
df = df.dropna()
path = 'C:/Users/Ewunetie/OneDrive - University of Gondar,/2022-2023 files/Courses/ML Project/Data/Preprocessed'
output_file_path = os.path.join(path,"Aug_44000.csv")
df.to_csv(output_file_path, index=False)
df

# %%
import pandas as pd
import os

file_path = 'C:/Users/Ewunetie/OneDrive - University of Gondar,/2022-2023 files/Courses/ML Project/Data/Preprocessed/mergid307.csv'
df = pd.read_csv(file_path)
df = df.dropna()
path = 'C:/Users/Ewunetie/OneDrive - University of Gondar,/2022-2023 files/Courses/ML Project/Data/Preprocessed'
output_file_path = os.path.join(path,"mergid307.csv")
df.to_csv(output_file_path, index=False)
df
# Out:
#             0         1         2         3         4         5         6  \
# 0   -0.491075 -0.063130 -0.187411 -0.104272 -0.173786 -0.152010 -0.189313
# 1   -0.404492  0.087182 -0.045648  0.042214 -0.026735  0.004298 -0.030825
# 2   -0.275418  0.279790  0.121232  0.210009  0.195863  0.194292  0.066317
# 3   -0.008036 -0.011756  0.007344 -0.014348 -0.021328 -0.007289 -0.018218
# 4   -0.096164 -0.093199 -0.107974 -0.112632 -0.104358 -0.041111 -0.045754
# ..        ...       ...       ...       ...       ...       ...       ...
# 149  0.011833 -0.024361 -0.013111  0.047955  0.029647 -0.016918  0.010233
# 150 -0.079042 -0.693346 -0.477761 -0.205492 -0.009832  0.083051  0.142343
# 151 -0.079196 -0.025498 -0.023203  0.004090 -0.024963  0.033291  0.053251
# 152 -0.177142 -0.197851 -0.212034 -0.163375 -0.136902 -0.112592 -0.095224
# 153  1.179551  0.556427 -0.037922 -0.480391 -0.314133 -0.303067 -0.252758
#
#             7         8         9  ...      1240      1241      1242  \
# ...
