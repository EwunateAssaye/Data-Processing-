# %%
import pandas as pd
import os

file1_path = 'C:/Users/Ewunetie/OneDrive - University of Gondar,/2022-2023 files/Courses/Project/data/Online data/125Hz/New folder/1 My collected data.csv'
df1 = pd.read_csv(file1_path)
df1
# Out:
#             0         1         2         3         4         5         6  \
# 0   -0.135028 -0.144889 -0.161987 -0.167553 -0.198610 -0.104766  0.247086
# 1   -0.124552 -0.163858 -0.168825 -0.169475 -0.199157 -0.108011  0.245754
# 2   -0.027809 -0.027887 -0.025471 -0.027630 -0.031252 -0.028455 -0.020327
# 3   -0.022336 -0.020462 -0.024121 -0.030244 -0.031223 -0.028785 -0.025700
# 4   -0.009978  0.014405  0.005023  0.001228 -0.001080  0.003378  0.004444
# ..        ...       ...       ...       ...       ...       ...       ...
# 496  0.239836  0.039456 -0.110748 -0.045213 -0.049505 -0.067116  0.049445
# 497  0.052142  0.310107  0.637753  0.626168  0.214828 -0.238015 -0.355158
# 498  0.126757  0.036770 -0.145170 -0.034136 -0.012952 -0.018546 -0.056654
# 499  0.130875  0.054178 -0.127979 -0.027147 -0.006950 -0.004867 -0.039609
# 500 -0.106696  0.000485 -0.026375  0.005842  0.002391  0.021126  0.009029
#
#             7         8         9  ...      1240      1241      1242  \
# ...

# %%
file2_path = 'C:/Users/Ewunetie/OneDrive - University of Gondar,/2022-2023 files/Courses/Project/data/Online data/125Hz/New folder/2 signal_ecg_sample_125_v4.csv'
df2 = pd.read_csv(file2_path)
df2
# Out:
#       -0.150303641  -0.086327668  -0.109574254  -0.106474308  -0.114658019  \
# 0        -0.136912     -0.236430     -0.291010     -0.339497     -0.354091
# 1        -0.078660     -0.195101     -0.139149     -0.159835     -0.141816
# 2        -0.185447     -0.207049     -0.188288     -0.194328     -0.189965
# 3         0.047063     -0.358773     -0.236029     -0.291722     -0.235620
# 4         0.118840      0.010144     -0.003689     -0.180391     -0.553172
# ...            ...           ...           ...           ...           ...
# 1138     -0.020953     -0.012757     -0.050930     -0.067832     -0.083968
# 1139      0.409985      0.728735      0.678320      0.684294      0.497954
# 1140     -0.020084     -0.036655     -0.011943     -0.036493     -0.032078
# 1141      0.492787      0.818636      0.808196      0.100999     -0.952834
# 1142      0.404492      0.515454      0.538250      0.572145      0.586357
#
# ...

# %%
concatenated_df = pd.concat([df1, df2])
concatenated_df
# Out:
#              0         1         2         3         4         5         6  \
# 0    -0.135028 -0.144889 -0.161987 -0.167553 -0.198610 -0.104766  0.247086
# 1    -0.124552 -0.163858 -0.168825 -0.169475 -0.199157 -0.108011  0.245754
# 2    -0.027809 -0.027887 -0.025471 -0.027630 -0.031252 -0.028455 -0.020327
# 3    -0.022336 -0.020462 -0.024121 -0.030244 -0.031223 -0.028785 -0.025700
# 4    -0.009978  0.014405  0.005023  0.001228 -0.001080  0.003378  0.004444
# ...        ...       ...       ...       ...       ...       ...       ...
# 1138       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1139       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1140       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1141       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1142       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
# ...

# %%
import pandas as pd
import os

# Replace 'file1.csv' and 'file2.csv' with the actual file paths
file1_path = 'C:/Users/Ewunetie/OneDrive - University of Gondar,/2022-2023 files/Courses/Project/data/Online data/125Hz/New folder/1 My collected data.csv'
file2_path = 'C:/Users/Ewunetie/OneDrive - University of Gondar,/2022-2023 files/Courses/Project/data/Online data/125Hz/New folder/2 signal_ecg_sample_125_v4.csv'

# Read CSV files into DataFrames
df1 = pd.read_csv(file1_path)
df2 = pd.read_csv(file2_path)

# Merge DataFrames based on the 'key' column
# merged_df = pd.merge(df1, df2, on='data_ID', how='inner')

# Concatenate DataFrames based on the 'key' column
concatenated_df = pd.concat([df1.set_index('data_ID'), df2.set_index('data_ID')], axis=1, join='outer')

# Reset the index to keep 'key' as a column
#concatenated_df.reset_index(inplace=False)
#concatenated_df

file_path = 'C:/Users/Ewunetie/OneDrive - University of Gondar,/2022-2023 files/Courses/Project/data/Online data/125Hz/New folder'

output_file_path = os.path.join(file_path,'result.csv')
concatenated_df.to_csv(output_file_path)
concatenated_df
# Out:
#              0         1         2         3         4         5         6  \
# 0    -0.135028 -0.144889 -0.161987 -0.167553 -0.198610 -0.104766  0.247086
# 1    -0.124552 -0.163858 -0.168825 -0.169475 -0.199157 -0.108011  0.245754
# 2    -0.027809 -0.027887 -0.025471 -0.027630 -0.031252 -0.028455 -0.020327
# 3    -0.022336 -0.020462 -0.024121 -0.030244 -0.031223 -0.028785 -0.025700
# 4    -0.009978  0.014405  0.005023  0.001228 -0.001080  0.003378  0.004444
# ...        ...       ...       ...       ...       ...       ...       ...
# 1138       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1139       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1140       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1141       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1142       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
# ...

# %%
# import pandas as pd
# import os

# # Replace 'directory' with the actual path to your CSV files
# directory = 'C:/Users/Ewunetie/OneDrive - University of Gondar,/2022-2023 files/Courses/Project/Final'

# # List all CSV files in the directory
# csv_files = [file for file in os.listdir(directory) if file.endswith('.csv')]

# # Create an empty list to store DataFrames
# dfs = []

# # Iterate over CSV files and read them into DataFrames
# for csv_file in csv_files:
#     file_path = os.path.join(directory, csv_file)
#     df = pd.read_csv(file_path)
#     # Assign a key based on the file name (without extension)
#     key = os.path.splitext(csv_file)[0]
#     # Add the DataFrame and key to the list
#     dfs.append((key, df))

# # Concatenate DataFrames using keys
# result = pd.concat(dict(dfs), axis=1)
# result=pd.DataFrame(result)

# # Display the concatenated DataFrame
# output_file_path = os.path.join(file_path,'result.csv')
# result.to_csv(output_file_path, index=False)
# result
