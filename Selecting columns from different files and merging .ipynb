# %%
import os
import pandas as pd
import numpy as np
df=pd.read_csv('C:/Users/Ewunetie/OneDrive - University of Gondar,/2022-2023 files/Courses/Project/data/Resampled/Mergedresampled.csv')
df
# Out:
#             0         1         2         3         4         5         6  \
# 0   -0.136222 -0.150206 -0.163140 -0.191757 -0.107290  0.365787  0.809060
# 1   -0.127060 -0.168157 -0.165247 -0.193576 -0.109179  0.363705  0.809022
# 2    0.025618  0.041932  0.007818 -0.003501 -0.028940 -0.031773 -0.025024
# 3    0.029050 -0.159847  0.045786  0.670125  1.007735  0.408357 -0.370413
# 4   -0.031637 -0.021608  0.034397  0.053408  0.049201  0.093579  0.160227
# ..        ...       ...       ...       ...       ...       ...       ...
# 121 -0.161524  0.160072  0.117544  0.129930  0.119454  0.151818  0.145181
# 122  0.130135  0.269372  0.144239  0.077655 -0.005802 -0.038507 -0.093025
# 123 -0.266898 -0.717478 -0.666404 -0.499669 -0.420224 -0.432488 -0.396975
# 124  0.024748  0.178055  0.191390  0.204236  0.212807  0.211175  0.150262
# 125 -0.075747 -0.094729 -0.064610 -0.062905 -0.059992 -0.049917 -0.073425
#
#             7         8         9  ...      1628      1629      1630  \
# ...

# %%
df1=pd.read_csv('C:/Users/Ewunetie/OneDrive - University of Gondar,/2022-2023 files/Courses/Project/data/clean_result.csv')
df1
# Out:
#         data_ID         0         1         2         3         4         5  \
# 0    A_01_06_06 -0.116201 -0.120952 -0.125470 -0.129755 -0.133807 -0.137628
# 1        A_01_1 -0.110777 -0.119968 -0.128788 -0.137072 -0.144673 -0.151463
# 2    A_01_17_07 -0.061985 -0.065903 -0.069614 -0.073117 -0.076413 -0.079501
# 3        A_01_2 -0.071215 -0.067523 -0.063781 -0.060007 -0.056219 -0.052437
# 4        A_01_3 -0.119150 -0.120002 -0.120831 -0.121598 -0.122282 -0.122872
# ..          ...       ...       ...       ...       ...       ...       ...
# 121     CB_07_5 -0.042867 -0.040006 -0.037546 -0.035554 -0.034082 -0.033164
# 122     CB_08_1 -0.024156 -0.023661 -0.023184 -0.022735 -0.022320 -0.021945
# 123     CB_08_2 -0.019543 -0.022498 -0.025228 -0.027804 -0.030297 -0.032774
# 124     CB_08_3 -0.064041 -0.065549 -0.067094 -0.068611 -0.070035 -0.071309
# 125     CB_08_4 -0.010116 -0.014700 -0.018962 -0.022896 -0.026501 -0.029784
#
# ...

# %%
df2=['BPM','HRV','R_peak','QRS_Complex','P_peak','T_peak','PR_interval','QT_interval','RR_interval','PR_segment','ST_segment']
df2
# Out:
# ['BPM',
#  'HRV',
#  'R_peak',
#  'QRS_Complex',
#  'P_peak',
#  'T_peak',
#  'PR_interval',
#  'QT_interval',
#  'RR_interval',
#  'PR_segment',
#  'ST_segment']

# %%
df3=df1[df2]
df3
# Out:
#       BPM       HRV    R_peak  QRS_Complex    P_peak    T_peak  PR_interval  \
# 0    82.0  0.000062  0.848918     0.146333  0.029415  0.233496     0.099543
# 1    83.0  0.007079  0.901995     0.091805  0.054954  0.275555     0.119171
# 2    76.0  0.001680  0.912266     0.139893  0.068142  0.091531     0.098547
# 3    81.0  0.006956  0.933224     0.091987  0.054165  0.296779     0.119400
# 4    82.0  0.008234  0.923682     0.091901  0.054138  0.284925     0.119160
# ..    ...       ...       ...          ...       ...       ...          ...
# 121  67.0  0.007000  0.987689     0.091000  0.088114  0.307345     0.163621
# 122  69.0  0.008765  0.529334     0.098779  0.105228  0.189704     0.157765
# 123  70.0  0.009290  0.543880     0.098855  0.102838  0.188076     0.159609
# 124  72.0  0.010634  0.551972     0.099606  0.107354  0.186939     0.159493
# 125  79.0  0.010141  0.520269     0.099872  0.111028  0.177564     0.154064
#
#      QT_interval  RR_interval  PR_segment  ST_segment
# ...

# %%
concatenated_df = pd.concat([df, df3], axis=1, join='outer')
concatenated_df
# Out:
#             0         1         2         3         4         5         6  \
# 0   -0.136222 -0.150206 -0.163140 -0.191757 -0.107290  0.365787  0.809060
# 1   -0.127060 -0.168157 -0.165247 -0.193576 -0.109179  0.363705  0.809022
# 2    0.025618  0.041932  0.007818 -0.003501 -0.028940 -0.031773 -0.025024
# 3    0.029050 -0.159847  0.045786  0.670125  1.007735  0.408357 -0.370413
# 4   -0.031637 -0.021608  0.034397  0.053408  0.049201  0.093579  0.160227
# ..        ...       ...       ...       ...       ...       ...       ...
# 121 -0.161524  0.160072  0.117544  0.129930  0.119454  0.151818  0.145181
# 122  0.130135  0.269372  0.144239  0.077655 -0.005802 -0.038507 -0.093025
# 123 -0.266898 -0.717478 -0.666404 -0.499669 -0.420224 -0.432488 -0.396975
# 124  0.024748  0.178055  0.191390  0.204236  0.212807  0.211175  0.150262
# 125 -0.075747 -0.094729 -0.064610 -0.062905 -0.059992 -0.049917 -0.073425
#
#             7         8         9  ...       HRV    R_peak  QRS_Complex  \
# ...

# %%
output_file_path = os.path.join('C:/Users/Ewunetie/OneDrive - University of Gondar,/2022-2023 files/Courses/Project/data','resampled_result.csv')
concatenated_df.to_csv(output_file_path)
concatenated_df
# Out:
#             0         1         2         3         4         5         6  \
# 0   -0.136222 -0.150206 -0.163140 -0.191757 -0.107290  0.365787  0.809060
# 1   -0.127060 -0.168157 -0.165247 -0.193576 -0.109179  0.363705  0.809022
# 2    0.025618  0.041932  0.007818 -0.003501 -0.028940 -0.031773 -0.025024
# 3    0.029050 -0.159847  0.045786  0.670125  1.007735  0.408357 -0.370413
# 4   -0.031637 -0.021608  0.034397  0.053408  0.049201  0.093579  0.160227
# ..        ...       ...       ...       ...       ...       ...       ...
# 121 -0.161524  0.160072  0.117544  0.129930  0.119454  0.151818  0.145181
# 122  0.130135  0.269372  0.144239  0.077655 -0.005802 -0.038507 -0.093025
# 123 -0.266898 -0.717478 -0.666404 -0.499669 -0.420224 -0.432488 -0.396975
# 124  0.024748  0.178055  0.191390  0.204236  0.212807  0.211175  0.150262
# 125 -0.075747 -0.094729 -0.064610 -0.062905 -0.059992 -0.049917 -0.073425
#
#             7         8         9  ...       HRV    R_peak  QRS_Complex  \
# ...
