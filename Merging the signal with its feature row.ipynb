# %%
import pandas as pd
import os

folder_path1 = 'C:/Users/Ewunetie/OneDrive - University of Gondar,/2022-2023 files/Courses/Project/CTRL/Chewing.csv'
folder_path2 = 'C:/Users/Ewunetie/OneDrive - University of Gondar,/2022-2023 files/Courses/Project/CTRL/Control.csv'
folder_path = 'C:/Users/Ewunetie/OneDrive - University of Gondar,/2022-2023 files/Courses/Project/CTRL'
df1 = pd.read_csv(folder_path1)
print(df1)
df2 = pd.read_csv(folder_path2)
print(df2)

dfs=pd.concat([df1, df2],axis=0)
df=pd.DataFrame(dfs)
print(df)

output_file_path = os.path.join(folder_path,"CTRL.csv")
df.to_csv(output_file_path, index=False)
df
# Out:
#        data_ID         0         1         2         3         4         5  \
# 0   A_01_06_06 -0.116201 -0.120952 -0.125470 -0.129755 -0.133807 -0.137628
# 1       A_01_1 -0.110777 -0.119968 -0.128788 -0.137072 -0.144673 -0.151463
# 2   A_01_17_07 -0.061985 -0.065903 -0.069614 -0.073117 -0.076413 -0.079501
# 3       A_01_2 -0.071215 -0.067523 -0.063781 -0.060007 -0.056219 -0.052437
# 4       A_01_3 -0.119150 -0.120002 -0.120831 -0.121598 -0.122282 -0.122872
# ..         ...       ...       ...       ...       ...       ...       ...
# 63      A_07_4 -0.042867 -0.040006 -0.037546 -0.035554 -0.034082 -0.033164
# 64      A_08_1  0.004036  0.017585  0.030874  0.043721  0.055952  0.067408
# 65      A_08_2 -0.087354 -0.086402 -0.085131 -0.083613 -0.081923 -0.080136
# 66      A_08_3 -0.007330 -0.009214 -0.011009 -0.012670 -0.014156 -0.015427
# 67      A_08_4 -0.014677 -0.015100 -0.015465 -0.015775 -0.016033 -0.016245
#
# ...
