# %%
import pandas as pd
import os

# load data having incomplete columns 

folder_path = 'C:/Users/Ewunetie/OneDrive - University of Gondar,/2022-2023 files/Courses/Project/data/Final/result.csv'
df = pd.read_csv(folder_path)

df = pd.DataFrame(df)
print(df)

# Drop columns with any missing values
df_cleaned = df.dropna(axis=0)
df_cleaned
print(df_cleaned)

# saving the cleaned file to
output_folder = 'C:/Users/Ewunetie/OneDrive - University of Gondar,/2022-2023 files/Courses/Project/data/Final'
output_file_path = os.path.join(output_folder,"clean_result.csv")
df_cleaned.to_csv(output_file_path, index=False)
df_cleaned
# Out:
#           data_ID         0         1         2         3         4         5  \
# 0      A_01_06_06 -0.116201 -0.120952 -0.125470 -0.129755 -0.133807 -0.137628
# 1          A_01_1 -0.110777 -0.119968 -0.128788 -0.137072 -0.144673 -0.151463
# 2      A_01_17_07 -0.061985 -0.065903 -0.069614 -0.073117 -0.076413 -0.079501
# 3          A_01_2 -0.071215 -0.067523 -0.063781 -0.060007 -0.056219 -0.052437
# 4          A_01_3 -0.119150 -0.120002 -0.120831 -0.121598 -0.122282 -0.122872
# ..            ...       ...       ...       ...       ...       ...       ...
# 150  C_04_06_06_3       NaN       NaN       NaN       NaN       NaN       NaN
# 151  C_04_06_06_4       NaN       NaN       NaN       NaN       NaN       NaN
# 152  C_04_06_06_5       NaN       NaN       NaN       NaN       NaN       NaN
# 153  C_05_26_07_5       NaN       NaN       NaN       NaN       NaN       NaN
# 154  C_05_26_07_6       NaN       NaN       NaN       NaN       NaN       NaN
#
# ...
