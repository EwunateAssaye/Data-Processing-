# %%
import pandas as pd
import os
#'BPM','HRV','R_peak','QRS_Complex','P_peak','T_peak','PR_interval','QT_interval','RR_interval','PR_segment','ST_segment',

folder_path = 'C:/Users/Ewunetie/OneDrive - University of Gondar,/2022-2023 files/Courses/Project/data/Resampled/resampled_result.csv'
filepath1 = 'C:/Users/Ewunetie/OneDrive - University of Gondar,/2022-2023 files/Courses/Project/data/Resampled'
df1 = pd.read_csv(folder_path)

#BPM data
df=df1.drop(columns=['HRV','R_peak','QRS_Complex','P_peak','T_peak','PR_interval','QT_interval','RR_interval',
                    'PR_segment','ST_segment'])
filename = 'BPM_data.csv'
filepath = os.path.join(filepath1, filename)
# Save the modified DataFrame back to the file
df.to_csv(filepath, index=False)

#HRV_data
df=df1.drop(columns=['BPM','R_peak','QRS_Complex','P_peak','T_peak','PR_interval','QT_interval','RR_interval',
                    'PR_segment','ST_segment'])
filename = 'HRV_data.csv'
filepath = os.path.join(filepath1, filename)
# Save the modified DataFrame back to the file
df.to_csv(filepath, index=False)

#R_peak_data
df=df1.drop(columns=['BPM','HRV','QRS_Complex','P_peak','T_peak','PR_interval','QT_interval','RR_interval',
                    'PR_segment','ST_segment'])
filename = 'R_peak_data.csv'
filepath = os.path.join(filepath1, filename)
# Save the modified DataFrame back to the file
df.to_csv(filepath, index=False)

#QRS_Complex_data
df=df1.drop(columns=['BPM','HRV','R_peak','P_peak','T_peak','PR_interval','QT_interval','RR_interval',
                    'PR_segment','ST_segment'])
filename = 'QRS_Complex_data.csv'
filepath = os.path.join(filepath1, filename)
# Save the modified DataFrame back to the file
df.to_csv(filepath, index=False)

#P_peak_data
df=df1.drop(columns=['BPM','HRV','R_peak','QRS_Complex','T_peak','PR_interval','QT_interval','RR_interval',
                    'PR_segment','ST_segment'])
filename = 'P_peak_data.csv'
filepath = os.path.join(filepath1, filename)
# Save the modified DataFrame back to the file
df.to_csv(filepath, index=False)

#T_peak_data
df=df1.drop(columns=['BPM','HRV','R_peak','QRS_Complex','P_peak','PR_interval','QT_interval','RR_interval',
                    'PR_segment','ST_segment'])
filename = 'T_peak_data.csv'
filepath = os.path.join(filepath1, filename)
# Save the modified DataFrame back to the file
df.to_csv(filepath, index=False)

#PR_interval_data
df=df1.drop(columns=['BPM','HRV','R_peak','QRS_Complex','P_peak','T_peak','QT_interval','RR_interval',
                    'PR_segment','ST_segment'])
filename = 'PR_interval_data.csv'
filepath = os.path.join(filepath1, filename)
# Save the modified DataFrame back to the file
df.to_csv(filepath, index=False)

#QT_interval_data
df=df1.drop(columns=['BPM','HRV','R_peak','QRS_Complex','P_peak','T_peak','PR_interval','RR_interval',
                    'PR_segment','ST_segment'])
filename = 'QT_interval_data.csv'
filepath = os.path.join(filepath1, filename)
# Save the modified DataFrame back to the file
df.to_csv(filepath, index=False)

#RR_interval_data
df=df1.drop(columns=['BPM','HRV','R_peak','QRS_Complex','P_peak','T_peak','PR_interval','QT_interval',
                    'PR_segment','ST_segment'])
filename = 'RR_interval_data.csv'
filepath = os.path.join(filepath1, filename)
# Save the modified DataFrame back to the file
df.to_csv(filepath, index=False)

#PR_segment_data
df=df1.drop(columns=['BPM','HRV','R_peak','QRS_Complex','P_peak','T_peak','PR_interval','QT_interval','RR_interval',
                    'ST_segment'])
filename = 'PR_segment_data.csv'
filepath = os.path.join(filepath1, filename)
# Save the modified DataFrame back to the file
df.to_csv(filepath, index=False)

#ST_segment_data
df=df1.drop(columns=['BPM','HRV','R_peak','QRS_Complex','P_peak','T_peak','PR_interval','QT_interval','RR_interval',
                    'PR_segment'])
filename = 'ST_segment_data.csv'
filepath = os.path.join(filepath1, filename)
# Save the modified DataFrame back to the file
df.to_csv(filepath, index=False)

# %%
folder_path = 'C:/Users/Ewunetie/OneDrive - University of Gondar,/2022-2023 files/Courses/Project/data/BPM_data.csv'
df = pd.read_csv(folder_path)
df
# Out:
#         data_ID         0         1         2         3         4         5  \
# 0    A_01_06_06 -0.116201 -0.120952 -0.125470 -0.129755 -0.133807 -0.137628
# 1        A_01_1 -0.110777 -0.119968 -0.128788 -0.137072 -0.144673 -0.151463
# 2    A_01_17_07 -0.061985 -0.065903 -0.069614 -0.073117 -0.076413 -0.079501
# 3        A_01_2 -0.071215 -0.067523 -0.063781 -0.060007 -0.056219 -0.052437
# 4        A_01_3 -0.119150 -0.120002 -0.120831 -0.121598 -0.122282 -0.122872
# ..          ...       ...       ...       ...       ...       ...       ...
# 121     CB_07_5 -0.042867 -0.040006 -0.037546 -0.035554 -0.034082 -0.033164
# 122     CB_08_1 -0.024156 -0.023661 -0.023184 -0.022735 -0.022320 -0.021945
# 123     CB_08_2 -0.019543 -0.022498 -0.025228 -0.027804 -0.030297 -0.032774
# 124     CB_08_3 -0.064041 -0.065549 -0.067094 -0.068611 -0.070035 -0.071309
# 125     CB_08_4 -0.010116 -0.014700 -0.018962 -0.022896 -0.026501 -0.029784
#
# ...
